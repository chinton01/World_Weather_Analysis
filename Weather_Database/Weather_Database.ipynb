# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# import random
import random

# %%
random.randint(-90,90)
# Out:
# -90

# %%
random.random()
# Out:
# 0.3672438423302131

# %% [raw]
# random_number = random.randint(-90, 89) + random.random()
# random_number

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
random.randrange(-90, 90, step=1)
# Out:
# -65

# %%
random.randrange(-90, 90, step=3)
# Out:
# 63

# %%
random.uniform(-90, 90)
# Out:
# -14.257851669242328

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# 48.75550716131977

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 54.41015488,  12.92397688,   7.76797931,   6.09595254,
#          1.75184486,  -2.84433904, -65.91717826,  10.11088   ,
#         66.87377456,  30.19188624,  36.82078088, -50.03100822,
#         10.15826387, -76.27142984, -69.14387242, -42.86533902,
#         58.60601818,  89.0238688 , -63.70133246,  31.89779612,
#        -59.88215256, -44.51264216,  70.97900495,  -9.30841205,
#        -15.68877083, -38.50206228,  28.46765118,  50.49025682,
#         76.99936109,  27.67732627, -59.69909483, -18.48099762,
#        -87.20727922, -87.6512433 ,  12.48950629,  85.99151317,
#        -35.24795225,  65.19799516,  55.26323547, -83.66604481,
#          4.94636959,  54.76044917, -50.7593917 ,  38.4897873 ,
#          7.25877299,  30.76783076,  87.79876971,  42.42439853,
#          8.39065701,  16.5337095 ])

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=2000)
# Out:
# 23.4 µs ± 245 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 2000.
# %timeit latitudes(2000)
# Out:
# 2.89 ms ± 20.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the requests library.
import requests 

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i, city in enumerate(cities):
        # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_weather = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_weather})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | tangi
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | shirokiy
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | sucre
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | adrar
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | hoquiam
# Processing Record 16 of Set 1 | sabinas
# Processing Record 17 of Set 1 | kloulklubed
# Processing Record 18 of Set 1 | anadyr
# Processing Record 19 of Set 1 | nanortalik
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | shimoda
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | san policarpo
# Processing Record 27 of Set 1 | provideniya
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | padang
# Processing Record 30 of Set 1 | srednekolymsk
# Processing Record 31 of Set 1 | hesla
# Processing Record 32 of Set 1 | maine-soroa
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | hasaki
# Processing Record 36 of Set 1 | mount isa
# Processing Record 37 of Set 1 | cavallino
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | tabas
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | evensk
# Processing Record 45 of Set 1 | ambunti
# Processing Record 46 of Set 1 | yurimaguas
# Processing Record 47 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 1 | isangel
# Processing Record 49 of Set 1 | pak phanang
# Processing Record 50 of Set 1 | marawi
# Processing Record 1 of Set 2 | ascoli piceno
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | salalah
# Processing Record 4 of Set 2 | bandarbeyla
# Processing Record 5 of Set 2 | eydhafushi
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | taiping
# Processing Record 8 of Set 2 | soe
# Processing Record 9 of Set 2 | grindavik
# Processing Record 10 of Set 2 | indramayu
# Processing Record 11 of Set 2 | mae hong son
# Processing Record 12 of Set 2 | lorengau
# Processing Record 13 of Set 2 | souillac
# Processing Record 14 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 2 | itarema
# Processing Record 16 of Set 2 | touros
# Processing Record 17 of Set 2 | chumikan
# Processing Record 18 of Set 2 | portland
# Processing Record 19 of Set 2 | baykit
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | bowling green
# Processing Record 22 of Set 2 | lavrentiya
# Processing Record 23 of Set 2 | kaitangata
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 2 | awjilah
# Processing Record 26 of Set 2 | husavik
# Processing Record 27 of Set 2 | butaritari
# Processing Record 28 of Set 2 | naze
# Processing Record 29 of Set 2 | ambulu
# Processing Record 30 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | san cristobal
# Processing Record 33 of Set 2 | kemise
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | lisbon
# Processing Record 37 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 2 | denpasar
# Processing Record 39 of Set 2 | atar
# Processing Record 40 of Set 2 | gizo
# Processing Record 41 of Set 2 | ponta do sol
# Processing Record 42 of Set 2 | turukhansk
# Processing Record 43 of Set 2 | kahului
# Processing Record 44 of Set 2 | kedrovoye
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | tura
# Processing Record 48 of Set 2 | camacha
# Processing Record 49 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 2 | san andres
# Processing Record 1 of Set 3 | yumen
# Processing Record 2 of Set 3 | oranienburg
# Processing Record 3 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 3 | nantucket
# Processing Record 5 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | northam
# Processing Record 8 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 3 | hermanus
# Processing Record 10 of Set 3 | kodiak
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | hilo
# Processing Record 13 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 3 | olafsvik
# Processing Record 15 of Set 3 | ornskoldsvik
# Processing Record 16 of Set 3 | thinadhoo
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 3 | beboto
# Processing Record 20 of Set 3 | dombarovskiy
# Processing Record 21 of Set 3 | saint-leu
# Processing Record 22 of Set 3 | nome
# Processing Record 23 of Set 3 | grand gaube
# Processing Record 24 of Set 3 | guerrero negro
# Processing Record 25 of Set 3 | laguna
# Processing Record 26 of Set 3 | kapaa
# Processing Record 27 of Set 3 | port hedland
# Processing Record 28 of Set 3 | pocatello
# Processing Record 29 of Set 3 | ayan
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | prince rupert
# Processing Record 32 of Set 3 | marzuq
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | ulaangom
# Processing Record 35 of Set 3 | omsukchan
# Processing Record 36 of Set 3 | barda
# Processing Record 37 of Set 3 | karasjok
# Processing Record 38 of Set 3 | puntarenas
# Processing Record 39 of Set 3 | sabzevar
# Processing Record 40 of Set 3 | new norfolk
# Processing Record 41 of Set 3 | high level
# Processing Record 42 of Set 3 | jamestown
# Processing Record 43 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 3 | libres
# Processing Record 45 of Set 3 | hovd
# Processing Record 46 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 3 | tasiilaq
# Processing Record 48 of Set 3 | serowe
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | torbay
# Processing Record 1 of Set 4 | cape town
# Processing Record 2 of Set 4 | bara
# Processing Record 3 of Set 4 | cedar city
# Processing Record 4 of Set 4 | kajiado
# Processing Record 5 of Set 4 | tofield
# Processing Record 6 of Set 4 | kununurra
# Processing Record 7 of Set 4 | adolfo ruiz cortines
# Processing Record 8 of Set 4 | kashi
# Processing Record 9 of Set 4 | ukiah
# Processing Record 10 of Set 4 | palaia fokaia
# Processing Record 11 of Set 4 | mwingi
# Processing Record 12 of Set 4 | hailar
# Processing Record 13 of Set 4 | coos bay
# Processing Record 14 of Set 4 | narovchat
# Processing Record 15 of Set 4 | vao
# Processing Record 16 of Set 4 | springbok
# Processing Record 17 of Set 4 | wagar
# Processing Record 18 of Set 4 | agirish
# Processing Record 19 of Set 4 | dubbo
# Processing Record 20 of Set 4 | saint-philippe
# Processing Record 21 of Set 4 | hobyo
# Processing Record 22 of Set 4 | bitung
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | port blair
# Processing Record 25 of Set 4 | jalu
# Processing Record 26 of Set 4 | montemor-o-novo
# Processing Record 27 of Set 4 | nikolskoye
# Processing Record 28 of Set 4 | cherskiy
# Processing Record 29 of Set 4 | acapulco
# Processing Record 30 of Set 4 | duldurga
# Processing Record 31 of Set 4 | barrow
# Processing Record 32 of Set 4 | sainte-suzanne
# Processing Record 33 of Set 4 | castro
# Processing Record 34 of Set 4 | broken hill
# Processing Record 35 of Set 4 | rio gallegos
# Processing Record 36 of Set 4 | tuatapere
# Processing Record 37 of Set 4 | port elizabeth
# Processing Record 38 of Set 4 | viedma
# Processing Record 39 of Set 4 | chizhou
# Processing Record 40 of Set 4 | haines junction
# Processing Record 41 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 42 of Set 4 | xiongyue
# Processing Record 43 of Set 4 | norman
# Processing Record 44 of Set 4 | pokhara
# Processing Record 45 of Set 4 | okhotsk
# Processing Record 46 of Set 4 | xinmin
# Processing Record 47 of Set 4 | cabo san lucas
# Processing Record 48 of Set 4 | diapaga
# Processing Record 49 of Set 4 | saint-joseph
# Processing Record 50 of Set 4 | boyolangu
# Processing Record 1 of Set 5 | bocaiuva
# Processing Record 2 of Set 5 | necochea
# Processing Record 3 of Set 5 | khash
# Processing Record 4 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 5 of Set 5 | manicore
# Processing Record 6 of Set 5 | houston
# Processing Record 7 of Set 5 | henzada
# City not found. Skipping...
# Processing Record 8 of Set 5 | saint-pierre
# Processing Record 9 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 10 of Set 5 | lagoa
# Processing Record 11 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 13 of Set 5 | severo-kurilsk
# Processing Record 14 of Set 5 | pag
# Processing Record 15 of Set 5 | ust-tsilma
# Processing Record 16 of Set 5 | kaeo
# Processing Record 17 of Set 5 | poya
# Processing Record 18 of Set 5 | seoul
# Processing Record 19 of Set 5 | mahebourg
# Processing Record 20 of Set 5 | shawnee
# Processing Record 21 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 5 | beloha
# Processing Record 23 of Set 5 | verkhoyansk
# Processing Record 24 of Set 5 | leshukonskoye
# Processing Record 25 of Set 5 | haapiti
# Processing Record 26 of Set 5 | saskylakh
# Processing Record 27 of Set 5 | teya
# Processing Record 28 of Set 5 | springfield
# Processing Record 29 of Set 5 | zhongshu
# Processing Record 30 of Set 5 | kysyl-syr
# Processing Record 31 of Set 5 | kuytun
# Processing Record 32 of Set 5 | narsaq
# Processing Record 33 of Set 5 | itarantim
# Processing Record 34 of Set 5 | susanino
# Processing Record 35 of Set 5 | dikson
# Processing Record 36 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 5 | volkermarkt
# City not found. Skipping...
# Processing Record 38 of Set 5 | imbituba
# Processing Record 39 of Set 5 | yantal
# Processing Record 40 of Set 5 | arraial do cabo
# Processing Record 41 of Set 5 | talnakh
# Processing Record 42 of Set 5 | puerto escondido
# Processing Record 43 of Set 5 | ponta delgada
# Processing Record 44 of Set 5 | samarai
# Processing Record 45 of Set 5 | road town
# Processing Record 46 of Set 5 | bousso
# Processing Record 47 of Set 5 | dzilam gonzalez
# Processing Record 48 of Set 5 | yar-sale
# Processing Record 49 of Set 5 | aswan
# Processing Record 50 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 6 | coquimbo
# Processing Record 2 of Set 6 | katha
# City not found. Skipping...
# Processing Record 3 of Set 6 | bambous virieux
# Processing Record 4 of Set 6 | thompson
# Processing Record 5 of Set 6 | port macquarie
# Processing Record 6 of Set 6 | barranca de upia
# Processing Record 7 of Set 6 | fortuna
# Processing Record 8 of Set 6 | ewa beach
# Processing Record 9 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 6 | kabwe
# Processing Record 11 of Set 6 | ancud
# Processing Record 12 of Set 6 | kavaratti
# Processing Record 13 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 6 | vostok
# Processing Record 15 of Set 6 | cidreira
# Processing Record 16 of Set 6 | takoradi
# Processing Record 17 of Set 6 | araouane
# Processing Record 18 of Set 6 | jiuquan
# Processing Record 19 of Set 6 | namibe
# Processing Record 20 of Set 6 | rio grande
# Processing Record 21 of Set 6 | srikakulam
# Processing Record 22 of Set 6 | ilulissat
# Processing Record 23 of Set 6 | rondonopolis
# Processing Record 24 of Set 6 | sabha
# Processing Record 25 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 6 | salta
# Processing Record 27 of Set 6 | shanghai
# Processing Record 28 of Set 6 | kisangani
# Processing Record 29 of Set 6 | ulladulla
# Processing Record 30 of Set 6 | vega de alatorre
# Processing Record 31 of Set 6 | bowen
# Processing Record 32 of Set 6 | kilindoni
# Processing Record 33 of Set 6 | vardo
# Processing Record 34 of Set 6 | corowa
# Processing Record 35 of Set 6 | ahipara
# Processing Record 36 of Set 6 | ust-nera
# Processing Record 37 of Set 6 | nabire
# Processing Record 38 of Set 6 | saldanha
# Processing Record 39 of Set 6 | balikpapan
# Processing Record 40 of Set 6 | enshi
# Processing Record 41 of Set 6 | mariental
# Processing Record 42 of Set 6 | maunatlala
# Processing Record 43 of Set 6 | krasnogorskoye
# Processing Record 44 of Set 6 | rawson
# Processing Record 45 of Set 6 | tilichiki
# Processing Record 46 of Set 6 | muros
# Processing Record 47 of Set 6 | murom
# Processing Record 48 of Set 6 | bolshaya sosnova
# Processing Record 49 of Set 6 | esperance
# Processing Record 50 of Set 6 | hamilton
# Processing Record 1 of Set 7 | peniche
# Processing Record 2 of Set 7 | burnie
# Processing Record 3 of Set 7 | bairiki
# Processing Record 4 of Set 7 | nagato
# Processing Record 5 of Set 7 | higuey
# City not found. Skipping...
# Processing Record 6 of Set 7 | liberal
# Processing Record 7 of Set 7 | toora-khem
# Processing Record 8 of Set 7 | cardinal
# Processing Record 9 of Set 7 | san quintin
# Processing Record 10 of Set 7 | ondangwa
# Processing Record 11 of Set 7 | tomatlan
# Processing Record 12 of Set 7 | katsuura
# Processing Record 13 of Set 7 | fort stewart
# Processing Record 14 of Set 7 | klyuchi
# Processing Record 15 of Set 7 | nioro
# Processing Record 16 of Set 7 | bako
# Processing Record 17 of Set 7 | dabat
# Processing Record 18 of Set 7 | amazar
# Processing Record 19 of Set 7 | moron
# Processing Record 20 of Set 7 | kuntaur
# Processing Record 21 of Set 7 | vanimo
# Processing Record 22 of Set 7 | eenhana
# Processing Record 23 of Set 7 | iskateley
# Processing Record 24 of Set 7 | sistranda
# Processing Record 25 of Set 7 | severomuysk
# Processing Record 26 of Set 7 | borzya
# Processing Record 27 of Set 7 | onega
# Processing Record 28 of Set 7 | blagoyevo
# Processing Record 29 of Set 7 | airai
# Processing Record 30 of Set 7 | dongying
# Processing Record 31 of Set 7 | cayenne
# Processing Record 32 of Set 7 | manaure
# Processing Record 33 of Set 7 | bridlington
# Processing Record 34 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 7 | makakilo city
# Processing Record 36 of Set 7 | dargaville
# Processing Record 37 of Set 7 | bilgoraj
# Processing Record 38 of Set 7 | korem
# Processing Record 39 of Set 7 | mastic beach
# Processing Record 40 of Set 7 | norman wells
# Processing Record 41 of Set 7 | kyshtovka
# Processing Record 42 of Set 7 | luderitz
# Processing Record 43 of Set 7 | pocone
# Processing Record 44 of Set 7 | constitucion
# Processing Record 45 of Set 7 | tautira
# Processing Record 46 of Set 7 | qandala
# Processing Record 47 of Set 7 | itaguai
# Processing Record 48 of Set 7 | buin
# Processing Record 49 of Set 7 | yulara
# Processing Record 50 of Set 7 | lac du bonnet
# Processing Record 1 of Set 8 | tecoanapa
# Processing Record 2 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 8 | oranjemund
# Processing Record 4 of Set 8 | novolugovoye
# Processing Record 5 of Set 8 | riyadh
# Processing Record 6 of Set 8 | mayumba
# Processing Record 7 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 8 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 8 | sawtell
# Processing Record 10 of Set 8 | buala
# Processing Record 11 of Set 8 | mersing
# Processing Record 12 of Set 8 | pisco
# Processing Record 13 of Set 8 | pacific grove
# Processing Record 14 of Set 8 | kefamenanu
# Processing Record 15 of Set 8 | chuy
# Processing Record 16 of Set 8 | san patricio
# Processing Record 17 of Set 8 | binghamton
# Processing Record 18 of Set 8 | pasighat
# Processing Record 19 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 8 | benjamin aceval
# Processing Record 21 of Set 8 | sorland
# Processing Record 22 of Set 8 | codrington
# Processing Record 23 of Set 8 | santa fe
# Processing Record 24 of Set 8 | trairi
# Processing Record 25 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 26 of Set 8 | paris
# Processing Record 27 of Set 8 | emerald
# Processing Record 28 of Set 8 | victoria
# Processing Record 29 of Set 8 | bulgan
# Processing Record 30 of Set 8 | najran
# Processing Record 31 of Set 8 | yalutorovsk
# Processing Record 32 of Set 8 | rexburg
# Processing Record 33 of Set 8 | uarini
# Processing Record 34 of Set 8 | scornicesti
# Processing Record 35 of Set 8 | caravelas
# Processing Record 36 of Set 8 | iquitos
# Processing Record 37 of Set 8 | mehamn
# Processing Record 38 of Set 8 | shingu
# Processing Record 39 of Set 8 | pangnirtung
# Processing Record 40 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 8 | san ignacio de sabaneta
# City not found. Skipping...
# Processing Record 42 of Set 8 | nowy dwor gdanski
# Processing Record 43 of Set 8 | bonthe
# Processing Record 44 of Set 8 | matara
# Processing Record 45 of Set 8 | zhigansk
# Processing Record 46 of Set 8 | sobolevo
# Processing Record 47 of Set 8 | zelenoborskiy
# Processing Record 48 of Set 8 | mildura
# Processing Record 49 of Set 8 | xinzhou
# Processing Record 50 of Set 8 | zhangye
# Processing Record 1 of Set 9 | suez
# Processing Record 2 of Set 9 | diffa
# Processing Record 3 of Set 9 | nemuro
# Processing Record 4 of Set 9 | sorong
# Processing Record 5 of Set 9 | dingli
# Processing Record 6 of Set 9 | taoudenni
# Processing Record 7 of Set 9 | havoysund
# Processing Record 8 of Set 9 | redding
# Processing Record 9 of Set 9 | sao joao da barra
# Processing Record 10 of Set 9 | filingue
# Processing Record 11 of Set 9 | joshimath
# Processing Record 12 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 9 | birjand
# Processing Record 14 of Set 9 | sri aman
# Processing Record 15 of Set 9 | tabulbah
# City not found. Skipping...
# Processing Record 16 of Set 9 | fare
# Processing Record 17 of Set 9 | filadelfia
# Processing Record 18 of Set 9 | ferrol
# Processing Record 19 of Set 9 | el dorado
# Processing Record 20 of Set 9 | lazaro cardenas
# Processing Record 21 of Set 9 | ouango
# Processing Record 22 of Set 9 | richards bay
# Processing Record 23 of Set 9 | beyneu
# Processing Record 24 of Set 9 | pindiga
# Processing Record 25 of Set 9 | pangkalanbuun
# Processing Record 26 of Set 9 | muisne
# Processing Record 27 of Set 9 | sompeta
# Processing Record 28 of Set 9 | lasa
# Processing Record 29 of Set 9 | vila franca do campo
# Processing Record 30 of Set 9 | biak
# Processing Record 31 of Set 9 | fonte boa
# Processing Record 32 of Set 9 | eyl
# Processing Record 33 of Set 9 | te anau
# Processing Record 34 of Set 9 | sangmelima
# Processing Record 35 of Set 9 | henties bay
# Processing Record 36 of Set 9 | tessaoua
# Processing Record 37 of Set 9 | hakvik
# City not found. Skipping...
# Processing Record 38 of Set 9 | hervey bay
# Processing Record 39 of Set 9 | navalmoral de la mata
# Processing Record 40 of Set 9 | asfi
# Processing Record 41 of Set 9 | burns lake
# Processing Record 42 of Set 9 | pagondas
# City not found. Skipping...
# Processing Record 43 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 9 | emba
# Processing Record 45 of Set 9 | raha
# Processing Record 46 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 9 | rocha
# Processing Record 48 of Set 9 | kieta
# Processing Record 49 of Set 9 | forestville
# Processing Record 50 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 10 | soyo
# Processing Record 2 of Set 10 | antalaha
# Processing Record 3 of Set 10 | hala
# Processing Record 4 of Set 10 | ossora
# Processing Record 5 of Set 10 | ardatov
# Processing Record 6 of Set 10 | gua musang
# Processing Record 7 of Set 10 | margate
# Processing Record 8 of Set 10 | minsk mazowiecki
# Processing Record 9 of Set 10 | tamiahua
# Processing Record 10 of Set 10 | huaibei
# Processing Record 11 of Set 10 | colac
# Processing Record 12 of Set 10 | asau
# Processing Record 13 of Set 10 | avera
# Processing Record 14 of Set 10 | mecca
# Processing Record 15 of Set 10 | vidisha
# Processing Record 16 of Set 10 | whitianga
# Processing Record 17 of Set 10 | severo-yeniseyskiy
# Processing Record 18 of Set 10 | praia
# Processing Record 19 of Set 10 | las vegas
# Processing Record 20 of Set 10 | juneau
# Processing Record 21 of Set 10 | krasnozerskoye
# Processing Record 22 of Set 10 | corpus christi
# Processing Record 23 of Set 10 | catamarca
# Processing Record 24 of Set 10 | inirida
# Processing Record 25 of Set 10 | lompoc
# Processing Record 26 of Set 10 | bonfim
# Processing Record 27 of Set 10 | san pedro de lloc
# Processing Record 28 of Set 10 | gat
# Processing Record 29 of Set 10 | smithers
# Processing Record 30 of Set 10 | san ignacio
# Processing Record 31 of Set 10 | grand forks
# Processing Record 32 of Set 10 | limbang
# Processing Record 33 of Set 10 | hualmay
# Processing Record 34 of Set 10 | chardara
# Processing Record 35 of Set 10 | nouadhibou
# Processing Record 36 of Set 10 | camabatela
# Processing Record 37 of Set 10 | castlemaine
# Processing Record 38 of Set 10 | chulman
# Processing Record 39 of Set 10 | tshela
# Processing Record 40 of Set 10 | coihaique
# Processing Record 41 of Set 10 | karakose
# City not found. Skipping...
# Processing Record 42 of Set 10 | sur
# Processing Record 43 of Set 10 | walvis bay
# Processing Record 44 of Set 10 | krasnoselkup
# Processing Record 45 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 46 of Set 10 | pemba
# Processing Record 47 of Set 10 | iqaluit
# Processing Record 48 of Set 10 | bubaque
# Processing Record 49 of Set 10 | sitka
# Processing Record 50 of Set 10 | doha
# Processing Record 1 of Set 11 | pevek
# Processing Record 2 of Set 11 | paamiut
# Processing Record 3 of Set 11 | ostrovnoy
# Processing Record 4 of Set 11 | moose factory
# Processing Record 5 of Set 11 | penzance
# Processing Record 6 of Set 11 | wewak
# Processing Record 7 of Set 11 | ambilobe
# Processing Record 8 of Set 11 | kavieng
# Processing Record 9 of Set 11 | kochki
# Processing Record 10 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 11 | otane
# Processing Record 12 of Set 11 | esmeraldas
# Processing Record 13 of Set 11 | keelung
# Processing Record 14 of Set 11 | komsomolskiy
# Processing Record 15 of Set 11 | laje
# Processing Record 16 of Set 11 | madarounfa
# Processing Record 17 of Set 11 | waipawa
# Processing Record 18 of Set 11 | weligama
# Processing Record 19 of Set 11 | cukai
# Processing Record 20 of Set 11 | taitung
# Processing Record 21 of Set 11 | la orilla
# Processing Record 22 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 23 of Set 11 | san angelo
# Processing Record 24 of Set 11 | coronado
# Processing Record 25 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 26 of Set 11 | sete
# Processing Record 27 of Set 11 | zapolyarnyy
# Processing Record 28 of Set 11 | klaksvik
# Processing Record 29 of Set 11 | sagua la grande
# Processing Record 30 of Set 11 | korla
# Processing Record 31 of Set 11 | kamakwie
# Processing Record 32 of Set 11 | kedrovyy
# Processing Record 33 of Set 11 | laiagam
# City not found. Skipping...
# Processing Record 34 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 11 | hokitika
# Processing Record 36 of Set 11 | balykshi
# Processing Record 37 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 11 | svetlyy
# Processing Record 39 of Set 11 | uzyn
# Processing Record 40 of Set 11 | khandyga
# Processing Record 41 of Set 11 | flinders
# Processing Record 42 of Set 11 | belyy yar
# Processing Record 43 of Set 11 | lunenburg
# Processing Record 44 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 11 | aguimes
# Processing Record 46 of Set 11 | maceio
# Processing Record 47 of Set 11 | wenling
# Processing Record 48 of Set 11 | longyearbyen
# Processing Record 49 of Set 11 | qianan
# Processing Record 50 of Set 11 | esso
# Processing Record 1 of Set 12 | omboue
# Processing Record 2 of Set 12 | baracoa
# Processing Record 3 of Set 12 | mizdah
# Processing Record 4 of Set 12 | kamennogorsk
# Processing Record 5 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 6 of Set 12 | arnprior
# Processing Record 7 of Set 12 | fairbanks
# Processing Record 8 of Set 12 | cubara
# Processing Record 9 of Set 12 | aksu
# Processing Record 10 of Set 12 | fairview
# Processing Record 11 of Set 12 | minab
# Processing Record 12 of Set 12 | nuevo progreso
# Processing Record 13 of Set 12 | manuk mangkaw
# Processing Record 14 of Set 12 | panzhihua
# Processing Record 15 of Set 12 | grand-santi
# Processing Record 16 of Set 12 | gornopravdinsk
# Processing Record 17 of Set 12 | oriximina
# Processing Record 18 of Set 12 | cabedelo
# Processing Record 19 of Set 12 | loandjili
# Processing Record 20 of Set 12 | tezu
# Processing Record 21 of Set 12 | pampa
# Processing Record 22 of Set 12 | maniitsoq
# Processing Record 23 of Set 12 | dubai
# Processing Record 24 of Set 12 | medianeira
# Processing Record 25 of Set 12 | tongzi
# Processing Record 26 of Set 12 | natal
# Processing Record 27 of Set 12 | angoche
# Processing Record 28 of Set 12 | ballina
# Processing Record 29 of Set 12 | west wendover
# Processing Record 30 of Set 12 | los llanos de aridane
# Processing Record 31 of Set 12 | berdyuzhye
# City not found. Skipping...
# Processing Record 32 of Set 12 | havre-saint-pierre
# Processing Record 33 of Set 12 | awbari
# Processing Record 34 of Set 12 | meulaboh
# Processing Record 35 of Set 12 | huarmey
# Processing Record 36 of Set 12 | hami
# Processing Record 37 of Set 12 | tres arroyos
# Processing Record 38 of Set 12 | kericho
# Processing Record 39 of Set 12 | ha
# City not found. Skipping...
# Processing Record 40 of Set 12 | umm lajj
# Processing Record 41 of Set 12 | pimampiro
# Processing Record 42 of Set 12 | dorado
# Processing Record 43 of Set 12 | beringovskiy
# Processing Record 44 of Set 12 | nsanje
# Processing Record 45 of Set 12 | aklavik
# Processing Record 46 of Set 12 | skibbereen
# Processing Record 47 of Set 12 | wangaratta
# Processing Record 48 of Set 12 | solntsevo
# Processing Record 49 of Set 12 | vila velha
# Processing Record 50 of Set 12 | port hardy
# Processing Record 1 of Set 13 | gabu
# Processing Record 2 of Set 13 | wick
# Processing Record 3 of Set 13 | constantine
# Processing Record 4 of Set 13 | fort nelson
# Processing Record 5 of Set 13 | spirovo
# Processing Record 6 of Set 13 | ukwa
# Processing Record 7 of Set 13 | valparaiso
# Processing Record 8 of Set 13 | bokhan
# Processing Record 9 of Set 13 | gombong
# Processing Record 10 of Set 13 | dali
# Processing Record 11 of Set 13 | egvekinot
# Processing Record 12 of Set 13 | nishihara
# Processing Record 13 of Set 13 | labuhan
# Processing Record 14 of Set 13 | kamthi
# Processing Record 15 of Set 13 | altamira
# Processing Record 16 of Set 13 | la rioja
# Processing Record 17 of Set 13 | banjar
# Processing Record 18 of Set 13 | novikovo
# Processing Record 19 of Set 13 | maridi
# Processing Record 20 of Set 13 | salmas
# Processing Record 21 of Set 13 | fukue
# Processing Record 22 of Set 13 | pogoanele
# Processing Record 23 of Set 13 | janossomorja
# Processing Record 24 of Set 13 | surin
# Processing Record 25 of Set 13 | bassano
# Processing Record 26 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 13 | longyan
# Processing Record 28 of Set 13 | biltine
# Processing Record 29 of Set 13 | sioux lookout
# Processing Record 30 of Set 13 | mamontovo
# Processing Record 31 of Set 13 | north bend
# Processing Record 32 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 33 of Set 13 | agadez
# Processing Record 34 of Set 13 | we
# City not found. Skipping...
# Processing Record 35 of Set 13 | san jose de rio tinto
# Processing Record 36 of Set 13 | amga
# Processing Record 37 of Set 13 | luanda
# Processing Record 38 of Set 13 | noyabrsk
# Processing Record 39 of Set 13 | salisbury
# Processing Record 40 of Set 13 | welkom
# Processing Record 41 of Set 13 | bilma
# Processing Record 42 of Set 13 | bongandanga
# Processing Record 43 of Set 13 | nouakchott
# Processing Record 44 of Set 13 | ulundurpettai
# City not found. Skipping...
# Processing Record 45 of Set 13 | taltal
# Processing Record 46 of Set 13 | vytegra
# Processing Record 47 of Set 13 | balkanabat
# Processing Record 48 of Set 13 | urumqi
# Processing Record 49 of Set 13 | sayat
# Processing Record 50 of Set 13 | absam
# Processing Record 1 of Set 14 | whitehorse
# Processing Record 2 of Set 14 | pilar
# Processing Record 3 of Set 14 | altonia
# City not found. Skipping...
# Processing Record 4 of Set 14 | conceicao da barra
# Processing Record 5 of Set 14 | boone
# Processing Record 6 of Set 14 | orumiyeh
# Processing Record 7 of Set 14 | francavilla al mare
# Processing Record 8 of Set 14 | nador
# Processing Record 9 of Set 14 | barcelona
# Processing Record 10 of Set 14 | russell
# Processing Record 11 of Set 14 | batticaloa
# Processing Record 12 of Set 14 | stornoway
# Processing Record 13 of Set 14 | pindobacu
# Processing Record 14 of Set 14 | hay river
# Processing Record 15 of Set 14 | port keats
# Processing Record 16 of Set 14 | yalta
# Processing Record 17 of Set 14 | ambon
# Processing Record 18 of Set 14 | mezobereny
# Processing Record 19 of Set 14 | hofn
# Processing Record 20 of Set 14 | nautla
# Processing Record 21 of Set 14 | lima
# Processing Record 22 of Set 14 | miyako
# Processing Record 23 of Set 14 | tessalit
# Processing Record 24 of Set 14 | dingle
# Processing Record 25 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 14 | nova olinda do norte
# Processing Record 27 of Set 14 | nizhniy kuranakh
# Processing Record 28 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 14 | longhua
# Processing Record 30 of Set 14 | la uribe
# City not found. Skipping...
# Processing Record 31 of Set 14 | pamekasan
# Processing Record 32 of Set 14 | sao felix do xingu
# Processing Record 33 of Set 14 | ust-ishim
# Processing Record 34 of Set 14 | kosino
# Processing Record 35 of Set 14 | dmitriyevka
# Processing Record 36 of Set 14 | port lincoln
# Processing Record 37 of Set 14 | manado
# Processing Record 38 of Set 14 | mount gambier
# Processing Record 39 of Set 14 | vilela
# Processing Record 40 of Set 14 | jimo
# Processing Record 41 of Set 14 | rudsar
# Processing Record 42 of Set 14 | cacule
# Processing Record 43 of Set 14 | churapcha
# Processing Record 44 of Set 14 | lazi
# Processing Record 45 of Set 14 | namatanai
# Processing Record 46 of Set 14 | subacius
# City not found. Skipping...
# Processing Record 47 of Set 14 | chapais
# Processing Record 48 of Set 14 | susanville
# Processing Record 49 of Set 14 | port moresby
# Processing Record 50 of Set 14 | vestmannaeyjar
# Processing Record 1 of Set 15 | houma
# Processing Record 2 of Set 15 | gharb
# City not found. Skipping...
# Processing Record 3 of Set 15 | iki-burul
# Processing Record 4 of Set 15 | teguise
# Processing Record 5 of Set 15 | koindu
# Processing Record 6 of Set 15 | thilogne
# City not found. Skipping...
# Processing Record 7 of Set 15 | saint-francois
# Processing Record 8 of Set 15 | cadillac
# Processing Record 9 of Set 15 | nakasongola
# Processing Record 10 of Set 15 | londoko
# Processing Record 11 of Set 15 | linjiang
# Processing Record 12 of Set 15 | derbent
# Processing Record 13 of Set 15 | lovington
# Processing Record 14 of Set 15 | nizhniy odes
# Processing Record 15 of Set 15 | flagstaff
# Processing Record 16 of Set 15 | fuling
# Processing Record 17 of Set 15 | silver city
# Processing Record 18 of Set 15 | kyrylivka
# Processing Record 19 of Set 15 | luena
# Processing Record 20 of Set 15 | raudeberg
# Processing Record 21 of Set 15 | berlevag
# Processing Record 22 of Set 15 | lerwick
# Processing Record 23 of Set 15 | lashio
# Processing Record 24 of Set 15 | wattegama
# Processing Record 25 of Set 15 | alice springs
# Processing Record 26 of Set 15 | north platte
# Processing Record 27 of Set 15 | altus
# Processing Record 28 of Set 15 | whyalla
# Processing Record 29 of Set 15 | manggar
# Processing Record 30 of Set 15 | payyannur
# Processing Record 31 of Set 15 | gerede
# Processing Record 32 of Set 15 | akureyri
# Processing Record 33 of Set 15 | abha
# Processing Record 34 of Set 15 | jiexiu
# Processing Record 35 of Set 15 | togur
# Processing Record 36 of Set 15 | stabat
# Processing Record 37 of Set 15 | stromness
# Processing Record 38 of Set 15 | ormara
# Processing Record 39 of Set 15 | turkistan
# Processing Record 40 of Set 15 | port pirie
# Processing Record 41 of Set 15 | hatten
# Processing Record 42 of Set 15 | salym
# Processing Record 43 of Set 15 | dongsheng
# Processing Record 44 of Set 15 | gunjur
# Processing Record 45 of Set 15 | solovetskiy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
new_city_data_df = pd.DataFrame(city_data)
# Reorder the Columns
#new_column_order = ["column1", "column8", "column9","column2", "column3", "column4", "column5", "column6", "column7" ]
#city_data_df[new_column_order].head(10)
new_city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Alfred -33.5906   26.8910     63.09        83         100
# 1  Punta Arenas -53.1500  -70.9167     48.31        71          75
# 2         Tiksi  71.6872  128.8694      4.75        81         100
# 3         Tangi  34.3006   71.6536     59.00        40           0
# 4  Kruisfontein -34.0033   24.7314     56.91        83         100
# 5        Atuona  -9.8000 -139.0333     78.35        73           1
# 6      Shirokiy  49.7580  129.5230     21.97        54         100
# 7         Vaini -21.2000 -175.2000     82.56        89          40
# 8         Sucre -19.0333  -65.2627     56.98        60         100
# 9          Lebu -37.6167  -73.6500     51.94        91           1
#
#    Wind Speed Country Current Description
# 0        6.17      ZA          light rain
# 1       10.36      CL       broken clouds
# 2       19.62      RU     overcast clouds
# 3        5.21      PK           clear sky
# 4        3.83      ZA     overcast clouds
# 5       16.98      PF           clear sky
# 6       16.28      RU     overcast clouds
# 7        9.22      TO    scattered clouds
# 8        2.33      BO     overcast clouds
# 9       15.43      CL           clear sky

# %%
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
new_city_data_df[new_column_order]
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Port Alfred      ZA -33.5906   26.8910     63.09        83         100
# 1    Punta Arenas      CL -53.1500  -70.9167     48.31        71          75
# 2           Tiksi      RU  71.6872  128.8694      4.75        81         100
# 3           Tangi      PK  34.3006   71.6536     59.00        40           0
# 4    Kruisfontein      ZA -34.0033   24.7314     56.91        83         100
# ..            ...     ...      ...       ...       ...       ...         ...
# 671    Port Pirie      AU -33.1833  138.0167     68.09        64          61
# 672        Hatten      DE  53.0167    8.3500     46.62        93         100
# 673         Salym      RU  60.0625   71.4789     33.10        98         100
# 674     Dongsheng      CN  39.8161  109.9776     18.03        87         100
# 675        Gunjur      GM  13.2019  -16.7339     77.07        94          90
#
#      Wind Speed Current Description
# 0          6.17          light rain
# 1         10.36       broken clouds
# 2         19.62     overcast clouds
# 3          5.21           clear sky
# 4          3.83     overcast clouds
# ..          ...                 ...
# 671       16.93       broken clouds
# 672        4.00     overcast clouds
# 673        8.61     overcast clouds
# 674       28.70          light snow
# 675        4.61     overcast clouds
#
# [676 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
new_city_data_df.to_csv(output_data_file, index_label="City_ID")
